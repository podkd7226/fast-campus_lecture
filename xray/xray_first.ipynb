# %% [markdown]
# # **GPT의 기본 사용법을 이해**
#
# * model list
#     * o1 series,
#     * gpt-4o series: 일자별로 버전이 다름, 대동소이함
#     * gpt-4o mini: 경량 모델, 가격이 저렴하여 다양한 작업에 도움이 됨.
#
# * 사이트: https://platform.openai.com/docs/models

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### OpenAI의 기본맛을 보자
#
# * 1. api_key를 발급받아야한다.
# * https://openai.com/index/openai-api/
#
#
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. 다음으로 api key를 만든다. </br>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. 다음 화면
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. credit을 구매하자
#
#
# ![image.png](data:image/png;base64,...)

# %%
from openai import OpenAI

# %%
api_key = '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'
client = OpenAI(
                api_key=api_key #개인 api_key
                )

# %%
client

# %%
# 기본 구조
message = "오늘 안개가 많이 꼈는데 운전할때 팁을 알려줘 "
gpt_model = ["gpt-4o-mini", "gpt-4o"]
response = client.chat.completions.create(
                model=gpt_model[0],
                messages = [{"role": "user", "content": message}],
                temperature=0.3)

reply = response.choices[0].message.content
print(reply)
# Out:
# 안개가 낀 날 운전할 때는 안전을 최우선으로 고려해야 합니다. 다음은 안개 속에서 운전할 때 유용한 팁입니다:
#
# 1. **속도 줄이기**: 안개가 짙을 경우 시야가 제한되므로 속도를 줄여 안전한 운전을 해야 합니다.
#
# 2. **전조등 켜기**: 안개가 끼면 차량의 전조등을 켜서 다른 차량에 잘 보이도록 합니다. 안개등이 있다면 함께 사용하는 것이 좋습니다.
#
# 3. **차간 거리 유지**: 앞차와의 거리를 충분히 유지하여 갑작스러운 정지에 대비합니다.
#
# 4. **도로 표지판 및 차선 확인**: 도로의 차선이나 표지판을 잘 확인하며 운전합니다. 필요시 저속으로 주행하면서 주변 상황을 주의 깊게 살펴보세요.
#
# 5. **안개가 짙은 구간에서는 정지**: 시야가 너무 제한적일 경우, 안전한 장소에 차를 정차하고 잠시 대기하는 것도 좋은 방법입니다.
#
# 6. **사이드 미러와 백미러 점검**: 주변 차량의 위치를 확인하기 위해 사이드 미러와 백미러를 자주 점검합니다.
#
# 7. **소리 신호 사용**: 필요할 경우 경적을 사용하여 다른 운전자에게 자신의 존재를 알릴 수 있습니다.
#
# 8. **차량의 상태 점검**: 타이어, 브레이크, 와이퍼 등 차량의 상태를 미리 점검하여 안전한 운전이 가능하도록 합니다.
#
# 안개 속에서의 운전은 매우 위험할 수 있으니, 항상 주의 깊게 운전하시고 필요시 안전한 장소에서 대기하는 것이 좋습니다. 안전 운전하세요!

# %% [markdown]
# ### 어떻게 이와같은 답변을 얻을 수 있는지 이해한다.

# %%
gpt_model[0]
# Out:
# 'gpt-4o-mini'

# %%
gpt_model = ["gpt-4o-mini", "gpt-4o"]
response = client.chat.completions.create(
                model=gpt_model[1],
                messages = [{"role": "user", "content": "fast campus 소개해줘"}],
                temperature=0.3)

reply = response.choices[0].message.content
print(reply)
# Out:
# Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다.
#
# Fast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다.
#
# 이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.

# %%
print(response)
# 전반적인 내용이 나온다.
# Out:
# ChatCompletion(id='chatcmpl-C8H6Sh9I4YpaU96JJ2AQys93WWVKP', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다. \n\nFast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다. \n\n이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1756088404, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_46bff0e0c8', usage=CompletionUsage(completion_tokens=172, prompt_tokens=12, total_tokens=184, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt
# ...

# %%
# choices에 보면 대화에 대한 답변이 나온다.
response.choices
# Out:
# [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다. \n\nFast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다. \n\n이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))]

# %%
# [0]을 지정하는것은 대괄호 [] 안에 들어있는 0번째 내용을 가져오는 것을 말한다.
response.choices[0]
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다. \n\nFast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다. \n\n이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))

# %%
# 여기서 message를 선택해보자.
response.choices[0].message
# Out:
# ChatCompletionMessage(content='Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다. \n\nFast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다. \n\n이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
#content 내에 답변이 있다.
response.choices[0].message.content
# Out:
# 'Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다. \n\nFast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다. \n\n이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.'

# %%
reply = response.choices[0].message.content

# %%
print(reply)
# Out:
# Fast Campus는 주로 직장인과 취업 준비생을 대상으로 다양한 분야의 실무 교육을 제공하는 한국의 교육 기관입니다. 이곳은 특히 IT, 데이터 분석, 디자인, 마케팅, 비즈니스 등의 분야에서 실무에 바로 적용할 수 있는 교육 과정을 제공하는 것으로 유명합니다.
#
# Fast Campus의 교육 과정은 온라인과 오프라인 모두에서 제공되며, 수강생들이 실제 프로젝트를 통해 실무 경험을 쌓을 수 있도록 돕습니다. 또한, 각 분야의 전문가들이 강사로 참여하여 최신 트렌드와 실무 노하우를 공유합니다.
#
# 이 외에도 Fast Campus는 다양한 워크숍, 세미나, 네트워킹 이벤트 등을 통해 수강생들이 서로 교류하고 성장할 수 있는 기회를 제공합니다.

# %% [markdown]
# 결과 해석
#
# * ChatCompletion:
#   - response라고 기존에 client.chat.completions.create로 시작하는 함수의 결과를 받는다.
# * choices:
#   - 이중 choices의 안에 결과들이 들어온다. 우리는 그 중 message가 필요하다.
#
# * choices는 []로 쌓여진 list형태로 가져오므로 [0]이 필요하다.
#   - 이 안에 message안에 원하는 메세지가 들어있다.
#   - 그 안에 content에 실제 답변이 들어있는 형태로 되어있다.
#
#   따라서 결과적으로 이 모든것을 가져오려면 response.choices[0].message.content 로 불러와야한다.

# %% [markdown]
# # 주의사항
# * GPT-4는 전달 사용금액이 있고 한번이라고 결제가 된 계좌에 한해서만 사용이 가능합니다.
# * 추후 이에 대한 내용을 진행하실 분이라면, 지금 결제하여 사용하는것이 코드에 익숙해지고, 활용하는데 훨씬 도움이 됩니다. 비용은 본 수업에서 쓰는 정도는 천원도 들지 않습니다.

# %% [markdown]
# # 판독지에서 Semantic extraction을 시행
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 자동 판독문 구성 방식
# 1. **테이블(엑셀 혹은 csv)에 있는 판독문을 가져온다.**
# 2. **해당 판독문에 GPT로 labeling을 한다.**
# 3. labeling한 데이터를 parsing한다.
# 4. parsing 된 데이터를 다시 엑셀 혹은 csv 파일에 붙여넣는다.

# %% [markdown]
# ### pandas
# pandas는 데이터를 읽고 쓰고, 데이터를 정렬하고 필터링하고, 통계를 계산하는 데 사용되는 Python 라이브러리입니다.
#
# #### 장점
# * 테이블을 관리하는 데 특히 유용합니다. pandas를 사용하면 테이블을 쉽게 읽고 쓸 수 있습니다.
# * 또한, pandas를 사용하면 테이블을 정렬하고 필터링할 수 있습니다. 마지막으로, pandas를 사용하면 테이블에 대한 통계를 계산할 수 있습니다. pandas는 데이터 과학자, 데이터 분석가 및 기타 데이터를 조작해야 하는 사람들에게 유용한 도구입니다
#
# ```
# import pandas as pd
# ```
# * 제공된 파일 (short_text_mimic.csv)의 경로설정

# %%
import pandas as pd

# %%
dataset = pd.read_excel("./short_text_mimic.xlsx")

# %% [markdown]
# ### 데이터에 대한 의미
#
# * 출처: MIMIC dataset에서 chest X-ray관련 데이터만 추출 \
# https://physionet.org/content/mimic-cxr/2.0.0/
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# * note_id: 각 chest X-ray에 대한 ID
# * text: 각 X-ray에 대한 판독문

# %%
dataset[:10]
# Out:
#           note_id                                               text
# 0  10000032-RR-14  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1  10000032-RR-23  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 2  10000084-RR-12  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 3  10000102-RR-18  CHEST PA AND LATERAL.\n\nCOMPARISON:  None.\n\...
# 4  10000117-RR-13  EXAMINATION:   CHEST (PA AND LAT)\n\nINDICATIO...
# 5  10000117-RR-21  EXAMINATION:  Chest radiographs, PA and latera...
# 6   10000117-RR-8  CHEST RADIOGRAPH PERFORMED.\n\nCOMPARISON:  No...
# 7   10000473-RR-7  EXAMINATION:\nChest:  Frontal and lateral view...
# 8  10000560-RR-28  TWO-VIEW CHEST, ___.\n\nINDICATION:  Renal cel...
# 9  10000650-RR-16  INDICATION:  ___ man with fever and cough.\n\n...

# %%
dataset.loc[2]
# Out:
# note_id                                       10000084-RR-12
# text       EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# Name: 2, dtype: object

# %% [markdown]
# 의미: 2번째의 location에 있는 내용을 가져옴.
# * note_id :  10000084-RR-12
# * text: EXAMINATION: CHEST (PA AND LAT)\n\nINDICATION...
#
# ### 해야할일: 하나씩 판독지를 가져온다.

# %%
dataset.loc[2, 'text']
# Out:
# 'EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION:  History: ___ with weakness// ?PNA\n\nTECHNIQUE:  Chest PA and lateral\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nHeart size is mildly enlarged.  The mediastinal and hilar contours are\nunremarkable.  The pulmonary vasculature is normal. Lungs are hyperinflated\nwithout focal consolidation.  Streaky atelectasis is noted in the lung bases. \nNo pleural effusion or pneumothorax is seen. There are no acute osseous\nabnormalities.  Moderate to severe compression deformity of a low thoracic\nvertebral body is of indeterminate age.\n\nIMPRESSION: \n\nMild atelectasis in the lung bases without focal consolidation. \nAge-indeterminate moderate to severe compression deformity of a low thoracic\nvertebral body.\n'

# %%
print(dataset.loc[2, 'text'])
# Out:
# EXAMINATION:  CHEST (PA AND LAT)
#
# INDICATION:  History: ___ with weakness// ?PNA
#
# TECHNIQUE:  Chest PA and lateral
#
# COMPARISON:  None.
#
# FINDINGS:
#
# Heart size is mildly enlarged.  The mediastinal and hilar contours are
# unremarkable.  The pulmonary vasculature is normal. Lungs are hyperinflated
# without focal consolidation.  Streaky atelectasis is noted in the lung bases.
# No pleural effusion or pneumothorax is seen. There are no acute osseous
# abnormalities.  Moderate to severe compression deformity of a low thoracic
# vertebral body is of indeterminate age.
#
# IMPRESSION:
#
# Mild atelectasis in the lung bases without focal consolidation.
# Age-indeterminate moderate to severe compression deformity of a low thoracic
# vertebral body.

# %% [markdown]
#  **의미**
#
#  2행에 있는 text데이터를 가져왔다.
#
#  ### 해야할일
#
#  * 해당 데이터를 가져와서 내가 원하는 프롬프트에 입력한다.
#  * f-string

# %%
prompt = """다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes, 없으면 no라고 대답해줘.
           판독지:
           EXAMINATION:  CHEST (PA AND LAT)

          INDICATION:  ___ with new onset ascites  // eval for infection

          TECHNIQUE:  Chest PA and lateral

          COMPARISON:  None.

          FINDINGS:

          There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral
          nodular opacities that most likely represent nipple shadows. The
          cardiomediastinal silhouette is normal.  Clips project over the left lung,
          potentially within the breast. The imaged upper abdomen is unremarkable.
          Chronic deformity of the posterior left sixth and seventh ribs are noted.

          IMPRESSION:

          No acute cardiopulmonary process."""
response = client.chat.completions.create(
                model="gpt-4o-mini",
                messages = [{"role": "user", "content": prompt}],
                temperature=0.7)

# %%
#여기에 답변이 있다.
response.choices[0].message.content
# Out:
# 'no'

# %% [markdown]
# ### 해야할일 완료
#
# * 이렇게 하나씩 프롬프트를 짜서 넣으면 된다.
# * 그런데 계속 복사 붙여넣기를 할 순 없고 자동화가 필요하다.
# * 어떻게?

# %%
f"안녕하세요 이것은 fstring입니다"
# Out:
# '안녕하세요 이것은 fstring입니다'

# %%
input_ = "패스트 캠퍼스 강의 예시"

# %%
f"안녕하세요 이것은 {input_}입니다"
# Out:
# '안녕하세요 이것은 패스트 캠퍼스 강의 예시입니다'

# %% [markdown]
# 이와 같이 특정한 문장에 원하는 input을 바꿔서 넣는것을 말한다.

# %%
radiology_text = dataset.loc[0, 'text']

input2 = f"""안녕하세요 이것은 판독문:
<시작>
       {radiology_text}
<끝>
입니다"""

# %%
print(input2)
# Out:
# 안녕하세요 이것은 판독문:
# <시작>
#        EXAMINATION:  CHEST (PA AND LAT)
#
# INDICATION:  ___ with new onset ascites  // eval for infection
#
# TECHNIQUE:  Chest PA and lateral
#
# COMPARISON:  None.
#
# FINDINGS:
#
# There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral
# nodular opacities that most likely represent nipple shadows. The
# cardiomediastinal silhouette is normal.  Clips project over the left lung,
# potentially within the breast. The imaged upper abdomen is unremarkable.
# Chronic deformity of the posterior left sixth and seventh ribs are noted.
#
# IMPRESSION:
#
# No acute cardiopulmonary process.
#
# <끝>
# 입니다

# %% [markdown]
# * 앞에 반드시 f를 넣어줘야만 작동한다.

# %%
prompt = """다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes라고 대답해줘. 판독지:
{radiology_text}"""
print(prompt)
# Out:
# 다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes라고 대답해줘. 판독지:
# {radiology_text}

# %%
prompt2 = f"""다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes라고 대답해줘. 판독지:
{radiology_text}"""
print(prompt2)
# Out:
# 다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes라고 대답해줘. 판독지:
# EXAMINATION:  CHEST (PA AND LAT)
#
# INDICATION:  ___ with new onset ascites  // eval for infection
#
# TECHNIQUE:  Chest PA and lateral
#
# COMPARISON:  None.
#
# FINDINGS:
#
# There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral
# nodular opacities that most likely represent nipple shadows. The
# cardiomediastinal silhouette is normal.  Clips project over the left lung,
# potentially within the breast. The imaged upper abdomen is unremarkable.
# Chronic deformity of the posterior left sixth and seventh ribs are noted.
#
# IMPRESSION:
#
# No acute cardiopulmonary process.

# %%
dataset.loc[3, 'text']
# Out:
# 'CHEST PA AND LATERAL.\n\nCOMPARISON:  None.\n\nHISTORY:  Cough.\n\nFINDINGS:  Cardiomediastinal and hilar contours are within normal limits.\nLungs are clear. There is no focal consolidation, effusion, or pneumothorax.\nThe osseous structures are grossly unremarkable.\n\nIMPRESSION:  No acute cardiopulmonary process.\n'

# %%
radiology_text = dataset.loc[3, 'text']

prompt3 = f"""다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes라고 하고 없으면  no라고 대답해줘. 판독지:
{radiology_text}"""
print("여기가 prompt3: ", prompt3, "\n 끝 \n")

response = client.chat.completions.create(
                model="gpt-4o",
                messages = [{"role": "user", "content": prompt3}],
                temperature=0.3)

print("답변:", response.choices[0].message.content)
# Out:
# 여기가 prompt3:  다음 문장에서 폐렴이 있는지를 추출해줘. 있으면 yes라고 하고 없으면  no라고 대답해줘. 판독지:
# CHEST PA AND LATERAL.
#
# COMPARISON:  None.
#
# HISTORY:  Cough.
#
# FINDINGS:  Cardiomediastinal and hilar contours are within normal limits.
# Lungs are clear. There is no focal consolidation, effusion, or pneumothorax.
# The osseous structures are grossly unremarkable.
#
# IMPRESSION:  No acute cardiopulmonary process.
#
#  끝
#
# 답변: no
